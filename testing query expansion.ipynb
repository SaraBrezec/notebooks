# %%
from gensim.models import KeyedVectors, FastText
from itertools import islice
from sklearn.feature_extraction.text import TfidfVectorizer


import json
import pandas as pd
import string
import numpy as np
import collections
import math

# import natural language toolkit
from nltk.corpus   import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
stop_words = stopwords.words('english')

# %%
wiki_en_align = './../data/fasttext/wiki.en.align.vec' #'../../data/fasttext/wiki.en.align.vec'
wiki_en_bin = './../data/fasttext/wiki.en.bin'

# %%
# get fasttext wiki embeddings for english
wv_wiki_en = KeyedVectors.load_word2vec_format(wiki_en_align)
print('english words {}'.format(len(list(wv_wiki_en.vocab.keys()))))

# %%
ft_wiki_en = FastText.load_fasttext_format(wiki_en_bin)

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)



def tokenized_query(text, stopwords):
    """Tokenizes, lowers words and removes stopwords from the document.
        Args:
            text (str): Text we want to tokenize.
            stopwords (list): List of words we want to remove from the tokenized text. 
        Returns:
            filtered_tokens (list): List of low case tokens wich does not contain stop words.
        """
    without_punctuations = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(without_punctuations)
    filtered = ([lemmatizer.lemmatize(w.lower(), get_wordnet_pos(w.lower())) for w in tokens if not w in stopwords])
    return filtered

def extend_tokens(token_list, model):
    """Extends token list by summing consecutive vector pairs.
        Args: 
            token_list (list): List of tokens we want to extend.
        Returns:
            extension (list): List of extensions.
            wv (Word2VecKeyedVectors): Word embeddings.
        """
    tokens = []
    if model_format == 'word2vec':
        for token in token_list:
            # check if the token is in the vocabulary
            if token in model.vocab.keys():
                tokens.append(token)
    if model_format == 'fasttext':
        for token in token_list:
            # check if the token is in the vocabulary
            if token in model.wv.vocab:
                tokens.append(token)
    extention = set()
    for i in range(len(tokens)-1):
        new_token = model.most_similar(positive=[tokens[i], tokens[i+1]])[0][0]
        extention.add(new_token)
    extention = list(extention)
    return extention

def candidate_expansion_terms(tokens, k, model, model_format):
    """Gets the candidate expansion terms"""
    candidates = set()
    if model_format == 'word2vec':
        for token in tokens:
            # check if the token is in the vocabulary
            if token in model.vocab.keys():
                result = model.similar_by_word(token)
                limit = k if len(result) > k else len(result)
                # iterate through the most similar words
                for i in range(limit):
                    candidates.add(result[i][0])
    elif model_format == 'fasttext':
        for token in tokens:
            # check if the token is in the vocabulary
            if token in model.wv.vocab:
                result = model.most_similar(token)
                limit = k if len(result) > k else len(result)
                # iterate through the most similar words
                for i in range(limit):
                    candidates.add(result[i][0])
    else:
        raise Exception('Model type incorrect')
    # return list of candidates
    candidates = list(candidates)
    return candidates

def similarity(token, token_list, model, model_format ):
    """calculates the similarity between word and list of words"""
    # calculate the similarity of the token to all tokens
    similarity = 0
    num_of_tokens = 0
    if model_format == 'word2vec':
        for toks in token_list:
            # check if the token is in the vocabulary
            if toks in model.vocab.keys():
                num_of_tokens += 1
                similarity += model.similarity(toks, token)
    elif model_format == 'fasttext':
        for toks in token_list:
            # check if the token is in the vocabulary
            if toks in model.wv.vocab:
                num_of_tokens += 1
                similarity += model.similarity(toks, token)
    else:
        raise Exception('Model type incorrect')
    return similarity/num_of_tokens


def get_similarity_pairs(tokens, candidates, wv, model_format):
    """Calculates similarity to tokens for list of candidates.
        Args: 
            tokens (list): List of tokens to wich similarity is calculated
            candidates (list): List of tokens for wich similarity is calculated.
            wv (Word2VecKeyedVectors): Word embeddings.
        Returns:
            similarity_pairs (list): List of tuples. Tuples are pairs of candidates and their similarity to tokens.
        """
    similarity_pairs = []
    for candidate in candidates:
        sim = similarity(candidate, tokens, wv, model_format)
        similarity_pairs.append((candidate, sim))
    # return the list of expansion terms with their similarities
    return similarity_pairs

# updated function
def pre_retrieval_KNN(query, k, wv, n, stop_words,model_format, extension=False):
    """Find n most similar tokens(candidates) to the given query, optional: 
        query can be extended, then the candidates are found for extended query.
        Args: 
            query (string): User query we want to expand.
            k (int): Number of nearest neighbours.
            wv (Word2VecKeyedVectors): Word embeddings.
            n (int): Number of candidates (with the highest simiarity) that is returned.
            stopwords (list): List of words we want to remove from the tokenized text. 
        Returns:
            candidate_list (list): List of n candidates with the highest similarity to query tokens.
        """
    tokens = tokenized_query(query, stop_words)
    if extension:
        extended = extend_tokens(tokens,wv)
        candidates = candidate_expansion_terms(tokens+extended, k, wv,model_format)
        candidates_sim = get_similarity_pairs(tokens+extended, candidates, wv, model_format)
    else:
        candidates = candidate_expansion_terms(tokens, k, wv,model_format)
        candidates_sim = get_similarity_pairs(tokens, candidates, wv, model_format)
    def takeSecond(elem):
        return elem[1]
    sort = sorted(candidates_sim, key=takeSecond)[::-1]
    candidate_list = []
    for tupl in sort:
        candidate_list.append(tupl[0])
    cleaned = [word for word in candidate_list if word.isalpha()]
    lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in cleaned]
    candidate_list = [w for w in lemmatized if w not in tokens]
    candidate_list = candidate_list[:n]
    return candidate_list

# %%
pre_retrieval_KNN('fishing and pollution', 10, ft_wiki_en, 10, stop_words, 'fasttext')
# Out:
# C:\Users\sarab\Miniconda3\envs\envirolens\lib\site-packages\ipykernel_launcher.py:68: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Users\sarab\Miniconda3\envs\envirolens\lib\site-packages\ipykernel_launcher.py:95: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# ['shellfishing',
#  'earpollution',
#  'flwfishing',
#  'biopollution',
#  'pollute',
#  'billfishing',
#  'sollution',
#  'gamefishing',
#  'pollut',
#  'antipollution']

# %%
pre_retrieval_KNN('fishing and pollution', 10, wv_wiki_en, 10, stop_words)
# Out:
# ['shellfishing',
#  'earpollution',
#  'flwfishing',
#  'biopollution',
#  'pollute',
#  'billfishing',
#  'sollution',
#  'gamefishing',
#  'pollut',
#  'antipollution']

# %%
pre_retrieval_KNN('underground fish water', 10, wv_wiki_en, 100, stop_words)
# Out:
# ['seawater',
#  'fishwater',
#  'groundwaters',
#  'sewage',
#  'groundwater',
#  'potable',
#  'undergrounding',
#  'undergrounders',
#  'ρwater',
#  'wastewater',
#  'undergrounded',
#  'undergroung',
#  'undergrounder',
#  'baitfish',
#  'undergroun',
#  'gamefish',
#  'shellfish',
#  'beakfish',
#  'undergroud',
#  'mudfishes',
#  'goldfish',
#  'milkfishes',
#  'billfish']

# %%
pre_retrieval_KNN('underground fish water', 10, wv_wiki_en, 20, stop_words)
# Out:
# ['seawater',
#  'fishwater',
#  'groundwaters',
#  'sewage',
#  'groundwater',
#  'potable',
#  'undergrounding',
#  'undergrounders',
#  'ρwater',
#  'wastewater',
#  'undergrounded',
#  'undergroung',
#  'undergrounder',
#  'baitfish',
#  'undergroun']

# %%
lemmatizer.lemmatize('stood', get_wordnet_pos('stood'))
# Out:
# 'stood'

# %%
len(pre_retrieval_KNN('underground fish water', 10, wv_wiki_en, 40, stop_words))
# Out:
# 23

# %%
len(pre_retrieval_KNN('underground fish water bull', 10, wv_wiki_en, 100, stop_words))
# Out:
# 32

# %%
# vsake beseda jih da 10 knn, dolzina lahko 100, verjetno omejitev ker bo doc_retrieval delal 100 let

# %%
# glej query modules za teste, search je zelo odvisen od stevila dokumentov, torej tokeniziranega queryja, 4 besede je ze veliko:
# 20 extensionov 12s,10 8s, 5 6s
# z dvema besedama pa za 20 extensionov 6s, 10 4s, 5 2s cca 2krat hitreje..

# %%
# adding annotations

# %%
import json
annotated_topics = []
with open('C:\\Users\\sarab\\work\\try\\TREC\\processed_data\\titles_annotated.jsonl', 'r') as file:
        for line in file: 
            dicti = json.loads(line)
            annotated_topics.append(dicti)

# %%
annotated_cleaned = {}

for dicti in annotated_topics:
    ID = dicti.get('id')
    
    annotated_cleaned[ID]={}
    text = dicti.get('text')
    tokenized_text = tokenized_query(text, stop_words)
    annotated_cleaned[ID]['text'] = text
    
    NE_list = dicti.get('annotations').get('NE')
    NE_tuples = []
    for NE in NE_list:
        NE_tuples.append((NE.get('text'),NE.get('type')))
    annotated_cleaned[ID]['NE'] = NE_tuples   
        
    wiki_list = dicti.get('annotations').get('wiki')
    wiki_words = []
    for wiki in wiki_list:
        name = wiki.get("name")
        if len(name.split()) > 1:
            wiki_words.append(name.lower())
    annotated_cleaned[ID]['wiki'] = wiki_words 
    
    annotated_words_list = dicti.get('annotations').get('annotatedWords').get("words")
    synonyms = []
    for word in annotated_words_list:
        syn_list = word.get('synonyms')
        for syn in syn_list:
            tokenized_syn= word_tokenize(syn)
            for w in tokenized_syn:
                w = w.lower()
                for l in w:
                    if not l.isalpha() and l != "-":
                        w = w.replace(l, " ")
                if w not in tokenized_text:
                    synonyms.append(w)
    annotated_cleaned[ID]['synonyms'] = synonyms

# %%
annotated_cleaned
# Out:
# {'301': {'text': 'International Organized Crime',
#   'NE': [],
#   'wiki': ['organized crime'],
#   'synonyms': ['law-breaking']},
#  '302': {'text': 'Poliomyelitis and Post-Polio',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['polio',
#    'infantile paralysis',
#    'acute anterior poliomyelitis']},
#  '303': {'text': 'Hubble Telescope Achievements',
#   'NE': [],
#   'wiki': ['hubble space telescope'],
#   'synonyms': ['edwin hubble',
#    'edwin powell hubble',
#    'scope',
#    'accomplishment']},
#  '304': {'text': 'Endangered Species (Mammals)',
#   'NE': [],
#   'wiki': ['endangered species'],
#   'synonyms': ['species', 'mammalian']},
#  '305': {'text': 'Most Dangerous Vehicles',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['unsafe',
#    'grave',
#    'grievous',
#    'serious',
#    'severe',
#    'life-threatening']},
#  '306': {'text': 'African Civilian Deaths',
#   'NE': [('African Civilian Deaths', 'MISC')],
#   'wiki': [],
#   'synonyms': ['decease',
#    'expiry',
#    'last',
#    'dying',
#    'demise',
#    'end',
#    'destruction']},
#  '307': {'text': 'New Hydroelectric Projects',
#   'NE': [],
#   'wiki': [],
#   'synonyms': []},
#  '308': {'text': 'Implant Dentistry',
#   'NE': [],
#   'wiki': ['dental implant'],
#   'synonyms': ['dental medicine', 'odontology']},
#  '309': {'text': 'Rap and Crime',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['blame',
#    'strike',
#    'tap',
#    'pat',
#    'rap music',
#    'hip-hop',
#    'knock',
#    'belt',
#    'whack',
#    'whang',
#    'law-breaking']},
#  '310': {'text': 'Radio Waves and Brain Cancer',
#   'NE': [],
#   'wiki': ['radio waves (roger waters song)', 'brain tumor'],
#   'synonyms': ['radiocommunication',
#    'wireless',
#    'radio receiver',
#    'receiving set',
#    'radio set',
#    'tuner',
#    'encephalon',
#    'brainpower',
#    'learning ability',
#    'mental capacity',
#    'mentality',
#    'wit',
#    'mind',
#    'head',
#    'psyche',
#    'nous',
#    'genius',
#    'mastermind',
#    'brainiac',
#    'einstein',
#    'malignant neoplastic disease',
#    'crab',
#    'cancer the crab',
#    'genus cancer']},
#  '311': {'text': 'Industrial Espionage',
#   'NE': [],
#   'wiki': ['industrial espionage'],
#   'synonyms': []},
#  '312': {'text': 'Hydroponics',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['aquiculture', 'tank farming']},
#  '313': {'text': 'Magnetic Levitation-Maglev',
#   'NE': [('Magnetic Levitation-Maglev', 'PERSON')],
#   'wiki': [],
#   'synonyms': ['magnetized', 'magnetised', 'attractive', 'charismatic']},
#  '314': {'text': 'Marine Vegetation',
#   'NE': [],
#   'wiki': ['united states marine corps'],
#   'synonyms': ['devil dog',
#    'leatherneck',
#    'shipboard soldier',
#    'flora',
#    'botany']},
#  '315': {'text': 'Unexplained Highway Accidents',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['main road', 'fortuity', 'chance event']},
#  '316': {'text': 'Polygamy Polyandry Polygyny',
#   'NE': [],
#   'wiki': [],
#   'synonyms': []},
#  '317': {'text': 'Unsolicited Faxes',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['unasked', 'facsimile', 'facsimile machine']},
#  '318': {'text': 'Best Retirement Country',
#   'NE': [],
#   'wiki': ['country music'],
#   'synonyms': ['topper',
#    'c  h  best',
#    'charles herbert best',
#    'retreat',
#    'state',
#    'land',
#    'nation',
#    'commonwealth',
#    'res publica',
#    'body politic',
#    'rural area',
#    'area']},
#  '319': {'text': 'New Fuel Sources',
#   'NE': [],
#   'wiki': ['fuel (band)'],
#   'synonyms': ['beginning',
#    'origin',
#    'root',
#    'rootage',
#    'informant',
#    'reference',
#    'seed',
#    'germ',
#    'generator',
#    'author',
#    'reservoir']},
#  '320': {'text': 'Undersea Fiber Optic Cable',
#   'NE': [],
#   'wiki': ['optical fiber connector', 'optical fiber', 'cable television'],
#   'synonyms': ['fibre',
#    'character',
#    'vulcanized fiber',
#    'eye',
#    'oculus',
#    'cablegram',
#    'overseas telegram',
#    'line',
#    'transmission line',
#    'cable length',
#    'cable s length',
#    'cable television',
#    'cable system',
#    'cable television service']},
#  '321': {'text': 'Women in Parliaments',
#   'NE': [],
#   'wiki': ['women political leaders'],
#   'synonyms': ['adult female',
#    'womanhood',
#    'fair sex',
#    'charwoman',
#    'char',
#    'cleaning woman',
#    'cleaning lady']},
#  '322': {'text': 'International Art Crime',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['fine art',
#    'artistic creation',
#    'artistic production',
#    'artistry',
#    'prowess',
#    'artwork',
#    'graphics',
#    'nontextual matter',
#    'law-breaking']},
#  '323': {'text': 'Literary/Journalistic Plagiarism',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['plagiarization', 'plagiarisation', 'piracy']},
#  '324': {'text': 'Argentine/British Relations',
#   'NE': [],
#   'wiki': ['united kingdom'],
#   'synonyms': ['relations', 'dealings']},
#  '325': {'text': 'Cult Lifestyles',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['fad',
#    'craze',
#    'furor',
#    'furore',
#    'rage',
#    'cultus',
#    'religious cult']},
#  '326': {'text': 'Ferry Sinkings',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['ferryboat', 'ferrying', 'sinking feeling']},
#  '327': {'text': 'Modern Slavery',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['modern font',
#    'bodoni',
#    'bodoni font',
#    'bondage',
#    'thrall',
#    'thralldom',
#    'thraldom',
#    'slaveholding']},
#  '328': {'text': 'Pope Beatifications',
#   'NE': [('Pope Beatifications', 'PERSON')],
#   'wiki': [],
#   'synonyms': ['catholic pope',
#    'roman catholic pope',
#    'pontiff',
#    'holy father',
#    'vicar of christ',
#    'bishop of rome',
#    'alexander pope']},
#  '329': {'text': 'Mexican Air Pollution',
#   'NE': [],
#   'wiki': ['air pollution'],
#   'synonyms': ['air travel',
#    'aviation',
#    'airwave',
#    'breeze',
#    'zephyr',
#    'gentle wind',
#    'aura',
#    'atmosphere',
#    'tune',
#    'melody',
#    'strain',
#    'melodic line',
#    'line',
#    'melodic phrase',
#    'befoulment',
#    'defilement',
#    'contamination']},
#  '330': {'text': 'Iran-Iraq Cooperation',
#   'NE': [],
#   'wiki': ['iran–iraq war'],
#   'synonyms': []},
#  '331': {'text': 'World Bank Criticism',
#   'NE': [],
#   'wiki': ['world bank'],
#   'synonyms': ['universe',
#    'existence',
#    'creation',
#    'cosmos',
#    'macrocosm',
#    'reality',
#    'domain',
#    'earth',
#    'globe',
#    'worldly concern',
#    'earthly concern',
#    'earth',
#    'populace',
#    'public',
#    'human race',
#    'humanity',
#    'humankind',
#    'human beings',
#    'humans',
#    'mankind',
#    'man',
#    'depository financial institution',
#    'banking concern',
#    'banking company',
#    'bank building',
#    'savings bank',
#    'coin bank',
#    'money box',
#    'cant',
#    'camber',
#    'unfavorable judgment',
#    'critique',
#    'literary criticism']},
#  '332': {'text': 'Income Tax Evasion',
#   'NE': [],
#   'wiki': ['tax evasion', 'income tax'],
#   'synonyms': ['taxation',
#    'revenue enhancement',
#    'equivocation',
#    'nonpayment',
#    'escape',
#    'dodging']},
#  '333': {'text': 'Antibiotics Bacteria Disease',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['antibiotic drug', 'bacterium']},
#  '334': {'text': 'Export Controls Cryptography',
#   'NE': [],
#   'wiki': ['control theory'],
#   'synonyms': ['exportation',
#    'cryptanalysis',
#    'cryptanalytics',
#    'cryptology',
#    'coding',
#    'secret writing',
#    'steganography']},
#  '335': {'text': 'Adoptive Biological Parents',
#   'NE': [],
#   'wiki': ['parents (magazine)'],
#   'synonyms': ['adopted', 'biologic']},
#  '336': {'text': 'Black Bear Attacks',
#   'NE': [],
#   'wiki': ['american black bear',
#    'race and ethnicity in the united states census'],
#   'synonyms': ['dark',
#    'sinister',
#    'bleak',
#    'dim',
#    'calamitous',
#    'disastrous',
#    'fatal',
#    'fateful',
#    'blackened',
#    'pitch-black',
#    'pitch-dark',
#    'grim',
#    'mordant',
#    'bootleg',
#    'black-market',
#    'contraband',
#    'smuggled',
#    'disgraceful',
#    'ignominious',
#    'inglorious',
#    'opprobrious',
#    'shameful',
#    'smutty',
#    'onslaught',
#    'onset',
#    'onrush',
#    'fire',
#    'flak',
#    'flack',
#    'blast',
#    'attempt',
#    'approach',
#    'plan of attack',
#    'tone-beginning']},
#  '337': {'text': 'Viral Hepatitis',
#   'NE': [],
#   'wiki': ['viral hepatitis'],
#   'synonyms': []},
#  '338': {'text': 'Risk of Aspirin',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['hazard',
#    'jeopardy',
#    'peril',
#    'endangerment',
#    'danger',
#    'risk of infection',
#    'risk of exposure',
#    'acetylsalicylic acid',
#    'bayer',
#    'empirin',
#    'st  joseph']},
#  '339': {'text': "Alzheimer's Drug Treatment",
#   'NE': [],
#   'wiki': ['drug rehabilitation', "alzheimer's disease"],
#   'synonyms': ['handling', 'discussion', 'discourse']},
#  '340': {'text': 'Land Mine Ban',
#   'NE': [],
#   'wiki': ['land mine', 'ban (title)'],
#   'synonyms': ['ground',
#    'soil',
#    'dry land',
#    'earth',
#    'solid ground',
#    'terra firma',
#    'domain',
#    'demesne',
#    'country',
#    'state',
#    'kingdom',
#    'realm',
#    'estate',
#    'landed estate',
#    'acres',
#    'nation',
#    'commonwealth',
#    'res publica',
#    'body politic',
#    'din land',
#    'edwin herbert land',
#    'farming',
#    'prohibition',
#    'proscription',
#    'banning',
#    'forbiddance',
#    'forbidding',
#    'bachelor of arts in nursing']},
#  '341': {'text': 'Airport Security',
#   'NE': [],
#   'wiki': ['airport security'],
#   'synonyms': ['airdrome',
#    'aerodrome',
#    'drome',
#    'certificate',
#    'security department',
#    'security measures',
#    'protection',
#    'security system',
#    'security measure',
#    'surety']},
#  '342': {'text': 'Diplomatic Expulsion',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['diplomatical',
#    'ejection',
#    'exclusion',
#    'riddance',
#    'extrusion',
#    'projection',
#    'forcing out']},
#  '343': {'text': 'Police Deaths',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['police force',
#    'constabulary',
#    'law',
#    'decease',
#    'expiry',
#    'last',
#    'dying',
#    'demise',
#    'end',
#    'destruction']},
#  '344': {'text': 'Abuses of E-Mail',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['maltreatment',
#    'ill-treatment',
#    'ill-usage',
#    'insult',
#    'revilement',
#    'contumely',
#    'vilification',
#    'misuse',
#    'electronic mail',
#    'e-mail']},
#  '345': {'text': 'Overseas Tobacco Sales',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['abroad',
#    'oversea',
#    'baccy',
#    'tobacco plant',
#    'cut-rate sale',
#    'sales event',
#    'sales agreement']},
#  '346': {'text': 'Educational Standards',
#   'NE': [],
#   'wiki': [],
#   'synonyms': []},
#  '347': {'text': 'Wildlife Extinction',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['defunctness',
#    'extermination',
#    'experimental extinction',
#    'extinguishing',
#    'quenching']},
#  '348': {'text': 'Agoraphobia', 'NE': [], 'wiki': [], 'synonyms': []},
#  '349': {'text': 'Metabolism',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['metamorphosis', 'metabolic process', 'metastasis']},
#  '350': {'text': 'Health and Computer Terminals',
#   'NE': [],
#   'wiki': ['computer terminal'],
#   'synonyms': ['wellness',
#    'computing machine',
#    'computing device',
#    'data processor',
#    'electronic computer',
#    'information processing system',
#    'calculator',
#    'reckoner',
#    'figurer',
#    'estimator',
#    'terminus',
#    'depot',
#    'pole']},
#  '351': {'text': 'Falkland petroleum exploration',
#   'NE': [],
#   'wiki': ['hydrocarbon exploration'],
#   'synonyms': ['crude oil',
#    'crude',
#    'rock oil',
#    'fossil oil',
#    'geographic expedition']},
#  '352': {'text': 'British Chunnel impact',
#   'NE': [],
#   'wiki': ['united kingdom', 'channel tunnel'],
#   'synonyms': ['channel tunnel',
#    'wallop',
#    'impingement',
#    'encroachment',
#    'shock']},
#  '353': {'text': 'Antarctica exploration',
#   'NE': [('Antarctica', 'LOCATION')],
#   'wiki': [],
#   'synonyms': ['antarctic continent', 'geographic expedition']},
#  '354': {'text': 'journalist risks',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['diarist',
#    'diary keeper',
#    'hazard',
#    'jeopardy',
#    'peril',
#    'endangerment',
#    'danger',
#    'risk of infection',
#    'risk of exposure']},
#  '355': {'text': 'ocean remote sensing',
#   'NE': [],
#   'wiki': ['remote sensing'],
#   'synonyms': ['sea', 'distant', 'outside', 'removed', 'outback', 'feel']},
#  '356': {'text': 'postmenopausal estrogen Britain',
#   'NE': [('Britain', 'LOCATION')],
#   'wiki': ['remote sensing'],
#   'synonyms': ['oestrogen',
#    'united kingdom',
#    'uk',
#    'u k',
#    ' ',
#    'great britain',
#    'gb',
#    'united kingdom of great britain and northern ireland']},
#  '357': {'text': 'territorial waters dispute',
#   'NE': [],
#   'wiki': ['territorial waters'],
#   'synonyms': ['h o',
#    'body of water',
#    'water system',
#    'water supply',
#    'urine',
#    'piss',
#    'pee',
#    'piddle',
#    'weewee',
#    'difference',
#    'difference of opinion',
#    'conflict',
#    'contravention']},
#  '358': {'text': 'blood-alcohol fatalities',
#   'NE': [],
#   'wiki': ['traffic collision', 'blood alcohol content'],
#   'synonyms': ['human death']},
#  '359': {'text': 'mutual fund predictors',
#   'NE': [],
#   'wiki': ['mutual fund'],
#   'synonyms': ['common',
#    'reciprocal',
#    'monetary fund',
#    'store',
#    'stock',
#    'investment company',
#    'investment trust',
#    'investment firm',
#    'forecaster',
#    'prognosticator',
#    'soothsayer']},
#  '360': {'text': 'drug legalization benefits',
#   'NE': [],
#   'wiki': ['drug liberalization'],
#   'synonyms': ['legalisation', 'legitimation', 'welfare']},
#  '361': {'text': 'clothing sweatshops',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['article of clothing',
#    'vesture',
#    'wear',
#    'wearable',
#    'habiliment']},
#  '362': {'text': 'human smuggling',
#   'NE': [],
#   'wiki': ['people smuggling', 'human rights'],
#   'synonyms': ['smuggling']},
#  '363': {'text': 'transportation tunnel disasters',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['transportation system',
#    'transit',
#    'transfer',
#    'transferral',
#    'conveyance',
#    'fare',
#    'department of transportation',
#    'dot',
#    'shipping',
#    'transport',
#    'exile',
#    'deportation',
#    'expatriation',
#    'burrow',
#    'catastrophe',
#    'calamity',
#    'tragedy',
#    'cataclysm']},
#  '364': {'text': 'rabies',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['hydrophobia', 'lyssa', 'madness']},
#  '365': {'text': 'El Nino',
#   'NE': [('El Nino', 'PERSON')],
#   'wiki': ['el niã±o'],
#   'synonyms': ['elevation',
#    'altitude',
#    'alt',
#    'elevated railway',
#    'elevated railroad',
#    'elevated',
#    'overhead railway']},
#  '366': {'text': 'commercial cyanide uses',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['nitrile',
#    'nitril',
#    'use',
#    'usage',
#    'utilization',
#    'utilisation',
#    'employment',
#    'exercise',
#    'function',
#    'purpose',
#    'role',
#    'consumption',
#    'economic consumption',
#    'usance',
#    'use of goods and services',
#    'habit',
#    'wont',
#    'enjoyment',
#    'manipulation']},
#  '367': {'text': 'piracy',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['buccaneering',
#    'plagiarism',
#    'plagiarization',
#    'plagiarisation']},
#  '368': {'text': 'in vitro fertilization',
#   'NE': [],
#   'wiki': ['in vitro fertilisation', 'in vitro'],
#   'synonyms': ['fertilisation', 'fecundation', 'impregnation', 'dressing']},
#  '369': {'text': 'anorexia nervosa bulimia',
#   'NE': [],
#   'wiki': ['anorexia nervosa', 'bulimia nervosa'],
#   'synonyms': ['binge-eating syndrome']},
#  '370': {'text': 'food/drug laws',
#   'NE': [],
#   'wiki': ['prohibition of drugs'],
#   'synonyms': ['jurisprudence',
#    'law of nature',
#    'natural law',
#    'practice of law',
#    'police',
#    'police force',
#    'constabulary',
#    'legal philosophy']},
#  '371': {'text': 'health insurance holistic',
#   'NE': [],
#   'wiki': ['health insurance'],
#   'synonyms': ['wellness', 'policy', 'insurance policy', 'indemnity']},
#  '372': {'text': 'Native American casino',
#   'NE': [('Native American', 'MISC')],
#   'wiki': ['native american gaming',
#    'race and ethnicity in the united states census'],
#   'synonyms': ['aboriginal', 'gambling casino', 'cassino']},
#  '373': {'text': 'encryption equipment export',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['encoding', 'exportation']},
#  '374': {'text': 'Nobel prize winners',
#   'NE': [('Nobel', 'MISC')],
#   'wiki': ['nobel prize'],
#   'synonyms': ['alfred nobel',
#    'alfred bernhard nobel',
#    'award',
#    'loot',
#    'booty',
#    'pillage',
#    'plunder',
#    'swag',
#    'dirty money',
#    'trophy',
#    'victor',
#    'achiever',
#    'success',
#    'succeeder']},
#  '375': {'text': 'hydrogen energy',
#   'NE': [],
#   'wiki': ['hydrogen fuel'],
#   'synonyms': ['h',
#    'atomic number  ',
#    'vigor',
#    'vigour',
#    'zip',
#    'push',
#    'get-up-and-go',
#    'muscularity',
#    'vim',
#    'vitality',
#    'department of energy',
#    'energy department',
#    'doe']},
#  '376': {'text': 'World Court',
#   'NE': [],
#   'wiki': ['international court of justice'],
#   'synonyms': ['universe',
#    'existence',
#    'creation',
#    'cosmos',
#    'macrocosm',
#    'reality',
#    'domain',
#    'earth',
#    'globe',
#    'worldly concern',
#    'earthly concern',
#    'earth',
#    'populace',
#    'public',
#    'human race',
#    'humanity',
#    'humankind',
#    'human beings',
#    'humans',
#    'mankind',
#    'man',
#    'tribunal',
#    'judicature',
#    'royal court',
#    'courtroom',
#    'courtyard',
#    'motor hotel',
#    'motor inn',
#    'motor lodge',
#    'tourist court',
#    'margaret court',
#    'homage']},
#  '377': {'text': 'cigar smoking', 'NE': [], 'wiki': [], 'synonyms': ['smoke']},
#  '378': {'text': 'euro opposition',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['resistance',
#    'oppositeness',
#    'confrontation',
#    'opponent',
#    'opposite',
#    'enemy',
#    'foe',
#    'foeman']},
#  '379': {'text': 'mainstreaming',
#   'NE': [],
#   'wiki': ['mainstreaming (education)'],
#   'synonyms': []},
#  '380': {'text': 'obesity medical treatment',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['fleshiness',
#    'corpulency',
#    'aesculapian',
#    'handling',
#    'discussion',
#    'discourse']},
#  '381': {'text': 'alternative medicine',
#   'NE': [],
#   'wiki': ['alternative medicine'],
#   'synonyms': ['alternate',
#    'mutually exclusive',
#    'medical specialty',
#    'medication',
#    'medicament',
#    'medicinal drug',
#    'practice of medicine',
#    'music']},
#  '382': {'text': 'hydrogen fuel automobiles',
#   'NE': [],
#   'wiki': ['hydrogen fuel'],
#   'synonyms': ['h', 'atomic number  ', 'car', 'auto', 'machine', 'motorcar']},
#  '383': {'text': 'mental illness drugs',
#   'NE': [],
#   'wiki': ['mental disorder'],
#   'synonyms': ['genial', 'unwellness', 'malady', 'sickness']},
#  '384': {'text': 'space station moon',
#   'NE': [],
#   'wiki': ['space station'],
#   'synonyms': ['infinite',
#    'blank',
#    'distance',
#    'blank space',
#    'place',
#    'quad',
#    'place',
#    'post',
#    'lunar month',
#    'lunation',
#    'synodic month',
#    'moonlight',
#    'moonshine',
#    'sun myung moon']},
#  '385': {'text': 'hybrid fuel cars',
#   'NE': [],
#   'wiki': ['hybrid (biology)'],
#   'synonyms': ['loanblend',
#    'loan-blend',
#    'crossbreed',
#    'cross',
#    'auto',
#    'automobile',
#    'machine',
#    'motorcar',
#    'railcar',
#    'railway car',
#    'railroad car',
#    'cable car',
#    'gondola',
#    'elevator car']},
#  '386': {'text': 'teaching disabled children',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['teaching',
#    'instruction',
#    'pedagogy',
#    'precept',
#    'commandment',
#    'education',
#    'didactics',
#    'educational activity',
#    'handicapped',
#    'hors de combat',
#    'out of action',
#    'kid',
#    'youngster',
#    'minor',
#    'shaver',
#    'nipper',
#    'small fry',
#    'tiddler',
#    'tike',
#    'tyke',
#    'fry',
#    'nestling',
#    'baby']},
#  '387': {'text': 'radioactive waste',
#   'NE': [],
#   'wiki': ['radioactive waste'],
#   'synonyms': ['waste material',
#    'waste matter',
#    'waste product',
#    'wastefulness',
#    'dissipation',
#    'thriftlessness',
#    'barren',
#    'wasteland',
#    'permissive waste']},
#  '388': {'text': 'organic soil enhancement',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['constituent',
#    'constitutional',
#    'constitutive',
#    'dirt',
#    'filth',
#    'grime',
#    'stain',
#    'grease',
#    'grunge',
#    'land',
#    'ground',
#    'territory',
#    'sweetening']},
#  '389': {'text': 'illegal technology transfer',
#   'NE': [],
#   'wiki': ['technology transfer'],
#   'synonyms': ['engineering',
#    'engineering science',
#    'applied science',
#    'transportation',
#    'transferral',
#    'conveyance',
#    'transferee',
#    'transference',
#    'transfer of training',
#    'carry-over']},
#  '390': {'text': 'orphan drugs',
#   'NE': [],
#   'wiki': ['orphan drug'],
#   'synonyms': []},
#  '391': {'text': 'R&D drug prices',
#   'NE': [],
#   'wiki': ['research and development'],
#   'synonyms': ['terms',
#    'damage',
#    'monetary value',
#    'cost',
#    'toll',
#    'leontyne price',
#    'mary leontyne price']},
#  '392': {'text': 'robotics',
#   'NE': [],
#   'wiki': ['research and development'],
#   'synonyms': []},
#  '393': {'text': 'mercy killing',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['clemency',
#    'mercifulness',
#    'killing',
#    'violent death',
#    'putting to death',
#    'cleanup']},
#  '394': {'text': 'home schooling',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['place',
#    'dwelling',
#    'domicile',
#    'abode',
#    'habitation',
#    'dwelling house',
#    'nursing home',
#    'rest home',
#    'base',
#    'family',
#    'household',
#    'house',
#    'menage',
#    'home plate',
#    'home base',
#    'plate',
#    'schooling']},
#  '395': {'text': 'tourism', 'NE': [], 'wiki': [], 'synonyms': ['touristry']},
#  '396': {'text': 'sick building syndrome',
#   'NE': [],
#   'wiki': ['sick building syndrome'],
#   'synonyms': ['ill',
#    'nauseated',
#    'nauseous',
#    'queasy',
#    'sickish',
#    'brainsick',
#    'crazy',
#    'demented',
#    'distracted',
#    'disturbed',
#    'mad',
#    'unbalanced',
#    'unhinged',
#    'disgusted',
#    'fed up',
#    'sick of',
#    'tired of',
#    'pale',
#    'pallid',
#    'wan',
#    'ghastly',
#    'grim',
#    'grisly',
#    'gruesome',
#    'macabre',
#    'edifice',
#    'construction']},
#  '397': {'text': 'automobile recalls',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['car',
#    'auto',
#    'machine',
#    'motorcar',
#    'remember',
#    'retrieve',
#    'call back',
#    'call up',
#    'recollect',
#    'think',
#    'hark back',
#    'return',
#    'come back',
#    'echo',
#    'call in',
#    'withdraw']},
#  '398': {'text': "dismantling Europe's arsenal",
#   'NE': [('Europe', 'LOCATION')],
#   'wiki': [],
#   'synonyms': ['level',
#    'raze',
#    'rase',
#    'tear down',
#    'take down',
#    'pull down',
#    'disassemble',
#    'take apart',
#    'break up',
#    'break apart',
#    'strip',
#    'european union',
#    'eu',
#    'european community',
#    'ec',
#    'european economic community',
#    'eec',
#    'common market',
#    'armory',
#    'armoury']},
#  '399': {'text': 'oceanographic vessels',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['vas', 'watercraft']},
#  '400': {'text': 'Amazon rain forest',
#   'NE': [('Amazon', 'ORGANIZATION')],
#   'wiki': ['amazon rainforest'],
#   'synonyms': ['virago',
#    'amazon river',
#    'rainfall',
#    'rainwater',
#    'pelting',
#    'wood',
#    'woods',
#    'woodland',
#    'timberland',
#    'timber']},
#  '401': {'text': 'foreign minorities, Germany',
#   'NE': [('Germany', 'LOCATION')],
#   'wiki': [],
#   'synonyms': ['strange',
#    'alien',
#    'extraneous',
#    'nonage',
#    'federal republic of germany',
#    'deutschland',
#    'frg']},
#  '402': {'text': 'behavioral genetics',
#   'NE': [],
#   'wiki': ['behavioural genetics'],
#   'synonyms': ['behavioural', 'genetic science']},
#  '403': {'text': 'osteoporosis', 'NE': [], 'wiki': [], 'synonyms': []},
#  '404': {'text': 'Ireland, peace talks',
#   'NE': [('Ireland', 'LOCATION')],
#   'wiki': ['northern ireland peace process'],
#   'synonyms': ['eire',
#    'irish free state',
#    'hibernia',
#    'emerald isle',
#    'peacefulness',
#    'peace of mind',
#    'repose',
#    'serenity',
#    'heartsease',
#    'ataraxis',
#    'public security',
#    'peace treaty',
#    'pacification',
#    'talking',
#    'lecture',
#    'public lecture',
#    'talk of the town']},
#  '405': {'text': 'cosmic events',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['case',
#    'consequence',
#    'effect',
#    'outcome',
#    'result',
#    'issue',
#    'upshot']},
#  '406': {'text': "Parkinson's disease",
#   'NE': [],
#   'wiki': ["parkinson's disease"],
#   'synonyms': ['james parkinson',
#    'c  northcote parkinson',
#    'cyril northcote parkinson']},
#  '407': {'text': 'poaching, wildlife preserves',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['continue',
#    'uphold',
#    'carry on',
#    'bear on',
#    'conserve',
#    'maintain',
#    'keep up',
#    'save',
#    'keep']},
#  '408': {'text': 'tropical storms',
#   'NE': [],
#   'wiki': ['tropical cyclone'],
#   'synonyms': ['tropic', 'violent storm', 'tempest']},
#  '409': {'text': 'legal, Pan Am, 103',
#   'NE': [('Pan Am', 'ORGANIZATION'), ('103', 'NUMBER')],
#   'wiki': ['pan american world airways'],
#   'synonyms': ['sound',
#    'effectual',
#    'cooking pan',
#    'goat god',
#    'genus pan',
#    'americium',
#    'am',
#    'atomic number   ',
#    'master of arts',
#    'ma',
#    'artium magister',
#    'am',
#    'amplitude modulation']},
#  '410': {'text': 'Schengen agreement',
#   'NE': [],
#   'wiki': ['schengen agreement'],
#   'synonyms': ['understanding',
#    'correspondence',
#    'accord',
#    'arrangement',
#    'concord']},
#  '411': {'text': 'salvaging, shipwreck, treasure',
#   'NE': [],
#   'wiki': ['marine salvage'],
#   'synonyms': ['salve',
#    'relieve',
#    'save',
#    'scavenge',
#    'wreck',
#    'hoarded wealth',
#    'gem']},
#  '412': {'text': 'airport security',
#   'NE': [],
#   'wiki': ['airport security'],
#   'synonyms': ['airdrome',
#    'aerodrome',
#    'drome',
#    'certificate',
#    'security department',
#    'security measures',
#    'protection',
#    'security system',
#    'security measure',
#    'surety']},
#  '413': {'text': 'steel production',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['sword', 'blade', 'brand', 'product', 'output', 'yield']},
#  '414': {'text': 'Cuba, sugar, exports',
#   'NE': [('Cuba', 'LOCATION')],
#   'wiki': [],
#   'synonyms': ['republic of cuba',
#    'refined sugar',
#    'carbohydrate',
#    'saccharide',
#    'boodle',
#    'bread',
#    'cabbage',
#    'clams',
#    'dinero',
#    'dough',
#    'gelt',
#    'kale',
#    'lettuce',
#    'lolly',
#    'lucre',
#    'loot',
#    'moolah',
#    'pelf',
#    'scratch',
#    'shekels',
#    'simoleons',
#    'wampum',
#    'exportation']},
#  '415': {'text': 'drugs, Golden Triangle',
#   'NE': [('Golden Triangle', 'PERSON')],
#   'wiki': ['golden triangle (southeast asia)'],
#   'synonyms': ['trigon', 'trilateral', 'triangulum']},
#  '416': {'text': 'Three Gorges Project',
#   'NE': [('Three Gorges Project', 'ORGANIZATION')],
#   'wiki': ['three gorges dam'],
#   'synonyms': ['undertaking', 'task', 'labor', 'projection']},
#  '417': {'text': 'creativity',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['creativeness', 'creative thinking']},
#  '418': {'text': 'quilts, income',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['comforter', 'puff']},
#  '419': {'text': 'recycle, automobile tires',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['reprocess',
#    'reuse',
#    'car',
#    'auto',
#    'machine',
#    'motorcar',
#    'tyre']},
#  '420': {'text': 'carbon monoxide poisoning',
#   'NE': [],
#   'wiki': ['carbon monoxide poisoning', 'carbon monoxide'],
#   'synonyms': ['c',
#    'atomic number  ',
#    'carbon paper',
#    'carbon copy',
#    'poisoning',
#    'toxic condition',
#    'intoxication']},
#  '421': {'text': 'industrial waste disposal',
#   'NE': [],
#   'wiki': ['industrial waste', 'waste management'],
#   'synonyms': ['waste material',
#    'waste matter',
#    'waste product',
#    'wastefulness',
#    'dissipation',
#    'thriftlessness',
#    'barren',
#    'wasteland',
#    'permissive waste',
#    'administration',
#    'disposition',
#    'electric pig',
#    'garbage disposal']},
#  '422': {'text': 'art, stolen, forged',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['fine art',
#    'artistic creation',
#    'artistic production',
#    'artistry',
#    'prowess',
#    'artwork',
#    'graphics',
#    'nontextual matter',
#    'slip',
#    'hammer',
#    'fake',
#    'counterfeit',
#    'invent',
#    'contrive',
#    'devise',
#    'excogitate',
#    'formulate',
#    'spurt',
#    'spirt',
#    'shape',
#    'form',
#    'work',
#    'mold',
#    'mould',
#    'fashion']},
#  '423': {'text': 'Milosevic, Mirjana Markovic',
#   'NE': [('Milosevic', 'PERSON'), ('Mirjana Markovic', 'PERSON')],
#   'wiki': ['olivera markoviä‡', 'mirjana markoviä‡'],
#   'synonyms': []},
#  '424': {'text': 'suicides',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['self-destruction', 'self-annihilation', 'felo-de-se']},
#  '425': {'text': 'counterfeiting money',
#   'NE': [],
#   'wiki': ['counterfeit money'],
#   'synonyms': ['forge', 'fake']},
#  '426': {'text': 'law enforcement, dogs',
#   'NE': [],
#   'wiki': ['law enforcement'],
#   'synonyms': ['jurisprudence',
#    'law of nature',
#    'natural law',
#    'practice of law',
#    'police',
#    'police force',
#    'constabulary',
#    'legal philosophy',
#    'domestic dog',
#    'canis familiaris',
#    'frump',
#    'cad',
#    'bounder',
#    'blackguard',
#    'hound',
#    'heel',
#    'frank',
#    'frankfurter',
#    'hotdog',
#    'hot dog',
#    'wiener',
#    'wienerwurst',
#    'weenie',
#    'pawl',
#    'detent',
#    'click',
#    'andiron',
#    'firedog',
#    'dog-iron']},
#  '427': {'text': 'UV damage, eyes',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['ultraviolet',
#    'ultraviolet radiation',
#    'ultraviolet light',
#    'ultraviolet illumination',
#    'harm',
#    'impairment',
#    'equipment casualty',
#    'hurt',
#    'scathe',
#    'price',
#    'terms',
#    'wrong',
#    'legal injury',
#    'oculus',
#    'optic',
#    'center',
#    'centre',
#    'middle',
#    'heart']},
#  '428': {'text': 'declining birth rates',
#   'NE': [],
#   'wiki': ['birth rate'],
#   'synonyms': ['worsen',
#    'refuse',
#    'reject',
#    'pass up',
#    'turn down',
#    'go down',
#    'wane',
#    'slump',
#    'correct',
#    'nativity',
#    'nascency',
#    'nascence',
#    'parturition',
#    'giving birth',
#    'birthing',
#    'parentage',
#    'charge per unit',
#    'pace']},
#  '429': {'text': "Legionnaires' disease",
#   'NE': [],
#   'wiki': ["legionnaires' disease"],
#   'synonyms': ['legionary']},
#  '430': {'text': 'killer bee attacks',
#   'NE': [],
#   'wiki': ['africanized bee'],
#   'synonyms': ['slayer',
#    'cause of death',
#    'killer whale',
#    'orca',
#    'grampus',
#    'sea wolf',
#    'orcinus orca',
#    'onslaught',
#    'onset',
#    'onrush',
#    'fire',
#    'flak',
#    'flack',
#    'blast',
#    'attempt',
#    'approach',
#    'plan of attack',
#    'tone-beginning']},
#  '431': {'text': 'robotic technology',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['engineering', 'engineering science', 'applied science']},
#  '432': {'text': 'profiling, motorists, police',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['profiling',
#    'automobilist',
#    'police force',
#    'constabulary',
#    'law']},
#  '433': {'text': 'Greek, philosophy, stoicism',
#   'NE': [('Greek', 'MISC')],
#   'wiki': ['greek language'],
#   'synonyms': ['grecian',
#    'hellenic',
#    'doctrine',
#    'philosophical system',
#    'school of thought',
#    'ism',
#    'stolidity',
#    'stolidness']},
#  '434': {'text': 'Estonia, economy',
#   'NE': [('Estonia', 'LOCATION')],
#   'wiki': [],
#   'synonyms': ['esthonia',
#    'republic of estonia',
#    'economic system',
#    'thriftiness',
#    'saving']},
#  '435': {'text': 'curbing population growth',
#   'NE': [],
#   'wiki': ['population growth'],
#   'synonyms': ['control',
#    'hold in',
#    'hold',
#    'contain',
#    'check',
#    'moderate',
#    'suppress',
#    'stamp down',
#    'inhibit',
#    'subdue',
#    'conquer',
#    'restrict',
#    'curtail',
#    'cut back',
#    'universe',
#    'growing',
#    'maturation',
#    'development',
#    'ontogeny',
#    'ontogenesis',
#    'increase',
#    'increment',
#    'emergence',
#    'outgrowth']},
#  '436': {'text': 'railway accidents',
#   'NE': [],
#   'wiki': ['train wreck', 'rail transport'],
#   'synonyms': ['railroad',
#    'railroad line',
#    'railway line',
#    'railway system',
#    'railroad track',
#    'fortuity',
#    'chance event']},
#  '437': {'text': 'deregulation, gas, electric',
#   'NE': [],
#   'wiki': ['natural gas'],
#   'synonyms': ['deregulating',
#    'gaseous state',
#    'gasoline',
#    'gasolene',
#    'petrol',
#    'flatulence',
#    'flatulency',
#    'accelerator',
#    'accelerator pedal',
#    'gas pedal',
#    'throttle',
#    'gun',
#    'natural gas',
#    'electrical',
#    'galvanic',
#    'galvanizing',
#    'galvanising']},
#  '438': {'text': 'tourism, increase',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['touristry',
#    'addition',
#    'gain',
#    'increment',
#    'growth',
#    'step-up']},
#  '439': {'text': 'inventions, scientific discoveries',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['innovation',
#    'excogitation',
#    'conception',
#    'design',
#    'find',
#    'uncovering',
#    'breakthrough']},
#  '440': {'text': 'child labor',
#   'NE': [],
#   'wiki': ['child labour'],
#   'synonyms': ['kid',
#    'youngster',
#    'minor',
#    'shaver',
#    'nipper',
#    'small fry',
#    'tiddler',
#    'tike',
#    'tyke',
#    'fry',
#    'nestling',
#    'baby',
#    'labour',
#    'toil',
#    'working class',
#    'proletariat',
#    'parturiency',
#    'confinement',
#    'lying-in',
#    'travail',
#    'childbed',
#    'labor movement',
#    'trade union movement',
#    'labour party',
#    'labour',
#    'labor party',
#    'department of labor',
#    'labor department',
#    'dol',
#    'undertaking',
#    'project',
#    'task']},
#  '441': {'text': 'Lyme disease',
#   'NE': [],
#   'wiki': ['lyme disease'],
#   'synonyms': []},
#  '442': {'text': 'heroic acts',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['epic',
#    'larger-than-life',
#    'heroical',
#    'expansive',
#    'grand',
#    'desperate',
#    'enactment',
#    'human action',
#    'human activity',
#    'routine',
#    'number',
#    'turn',
#    'bit']},
#  '443': {'text': 'U.S., investment, Africa',
#   'NE': [('U.S.', 'LOCATION'), ('Africa', 'LOCATION')],
#   'wiki': ['united states'],
#   'synonyms': ['united states government',
#    'united states',
#    'u s  government',
#    'us government',
#    'u s',
#    ' ',
#    'united states of america',
#    'america',
#    'the states',
#    'us',
#    'usa',
#    'u s a',
#    ' ',
#    'investing',
#    'investment funds',
#    'investiture']},
#  '444': {'text': 'supercritical fluids',
#   'NE': [],
#   'wiki': ['supercritical fluid'],
#   'synonyms': []},
#  '445': {'text': 'women clergy',
#   'NE': [],
#   'wiki': ['ordination of women'],
#   'synonyms': ['adult female',
#    'womanhood',
#    'fair sex',
#    'charwoman',
#    'char',
#    'cleaning woman',
#    'cleaning lady']},
#  '446': {'text': 'tourists, violence',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['tourer',
#    'holidaymaker',
#    'force',
#    'ferocity',
#    'fierceness',
#    'furiousness',
#    'fury',
#    'vehemence',
#    'wildness']},
#  '447': {'text': 'Stirling engine',
#   'NE': [],
#   'wiki': ['stirling engine'],
#   'synonyms': ['locomotive', 'locomotive engine', 'railway locomotive']},
#  '448': {'text': 'ship losses',
#   'NE': [],
#   'wiki': ['win–loss record (pitching)'],
#   'synonyms': ['red ink',
#    'red',
#    'deprivation',
#    'personnel casualty',
#    'passing',
#    'departure',
#    'exit',
#    'expiration',
#    'going',
#    'release']},
#  '449': {'text': 'antibiotics ineffectiveness',
#   'NE': [],
#   'wiki': [],
#   'synonyms': ['antibiotic drug', 'ineffectualness', 'ineffectuality']},
#  '450': {'text': 'King Hussein, peace',
#   'NE': [('Hussein', 'PERSON')],
#   'wiki': ['hussein of jordan'],
#   'synonyms': ['male monarch',
#    'rex',
#    'queen',
#    'world-beater',
#    'baron',
#    'big businessman',
#    'business leader',
#    'magnate',
#    'mogul',
#    'power',
#    'top executive',
#    'tycoon',
#    'billie jean king',
#    'billie jean moffitt king',
#    'b  b  king',
#    'riley b king',
#    'martin luther king',
#    'martin luther king jr',
#    ' ',
#    'husain',
#    'husayn',
#    'saddam hussein',
#    'saddam',
#    'saddam bin hussein at-takriti',
#    'ibn talal hussein',
#    'king hussein',
#    'peacefulness',
#    'peace of mind',
#    'repose',
#    'serenity',
#    'heartsease',
#    'ataraxis',
#    'public security',
#    'peace treaty',
#    'pacification']}}

# %%
# TREC testing annotations

# %%
from gensim.models import Word2Vec
